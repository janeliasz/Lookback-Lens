# %%
import pandas as pd

# %%
qa = pd.read_parquet('data/new_version_merged_df.parquet')

# %%
qa
# Out:
#                id dataset                                              query  \
# 0            nq_0      nq           who got the first nobel prize in physics
# 1            nq_1      nq     when is the next deadpool movie being released
# 2            nq_2      nq   the south west wind blows across nigeria between
# 3            nq_3      nq                 what does hp mean in war and order
# 4            nq_4      nq    who wrote the first declaration of human rights
# ...           ...     ...                                                ...
# 6219   bioask_440  bioask  Jaki jest odsetek osób reagujących na leczenie...
# 6220   bioask_715  bioask      Która kinaza jest hamowana przez Tripolinę A?
# 6221  bioask_1207  bioask  Jaka jest rola prognostyczna zmienionego profi...
# 6222  bioask_1327  bioask  Czy istnieje różnica w szybkości fuzji i rozsz...
# 6223   bioask_511  bioask  Czy mutacje BBS są związane z zespołową chorob...
#
# ...

# %%
cnndm = pd.read_parquet('data/cnndm.parquet')

# %%
cnndm
# Out:
#             id dataset                                           question  \
# 0      cnndm_0   cnndm  Generate a summary comprising of 1 sentence fo...
# 1      cnndm_1   cnndm  Generate a summary comprising of 1 sentence fo...
# 2      cnndm_2   cnndm  Generate a summary comprising of 1 sentence fo...
# 3      cnndm_3   cnndm  Generate a summary comprising of 1 sentence fo...
# 4      cnndm_4   cnndm  Generate a summary comprising of 1 sentence fo...
# ..         ...     ...                                                ...
# 995  cnndm_995   cnndm  Generate a summary comprising of 1 sentence fo...
# 996  cnndm_996   cnndm  Generate a summary comprising of 1 sentence fo...
# 997  cnndm_997   cnndm  Generate a summary comprising of 1 sentence fo...
# 998  cnndm_998   cnndm  Generate a summary comprising of 1 sentence fo...
# 999  cnndm_999   cnndm  Generate a summary comprising of 1 sentence fo...
#
#                                                context  \
# ...

# %%
xsum = pd.read_parquet('data/xsum_df.parquet')

# %%
xsum
# Out:
#                 id                                           question  \
# 0    xsum_38264402  Generate a summary comprising of 1 sentence fo...
# 1    xsum_38521798  Generate a summary comprising of 1 sentence fo...
# 2    xsum_27119429  Generate a summary comprising of 1 sentence fo...
# 3    xsum_18298438  Generate a summary comprising of 1 sentence fo...
# 4    xsum_40191593  Generate a summary comprising of 1 sentence fo...
# ..             ...                                                ...
# 995  xsum_38208884  Generate a summary comprising of 1 sentence fo...
# 996  xsum_39380075  Generate a summary comprising of 1 sentence fo...
# 997  xsum_39192785  Generate a summary comprising of 1 sentence fo...
# 998  xsum_39207593  Generate a summary comprising of 1 sentence fo...
# 999  xsum_35860140  Generate a summary comprising of 1 sentence fo...
#
#                                                context  \
# 0    `Dokument [1]:` Prison Link Cymru had 1,099 re...
# ...

# %%
full_ds = pd.read_parquet('data/full_hallu_ds.parquet')

# %%
full_ds
# Out:
#                 id dataset                                             query  \
# 0             nq_0      nq          who got the first nobel prize in physics
# 1             nq_1      nq    when is the next deadpool movie being released
# 2             nq_2      nq  the south west wind blows across nigeria between
# 3             nq_3      nq                what does hp mean in war and order
# 4             nq_4      nq   who wrote the first declaration of human rights
# ..             ...     ...                                               ...
# 995  xsum_38208884    xsum                                              None
# 996  xsum_39380075    xsum                                              None
# 997  xsum_39192785    xsum                                              None
# 998  xsum_39207593    xsum                                              None
# 999  xsum_35860140    xsum                                              None
#
# ...

# %%
import torch

# %%
test = torch.load('outputs/step01_cnndm_test.pt')

# %%
len(test)
# Out:
# 998
