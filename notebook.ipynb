# %%
print("hello")
# Out:
# hello

# %%
import torch

# %%
lbr = torch.load("lookback-ratio-cnndm-7b.pt")

# %%
lbr[0].keys()
# Out:
# dict_keys(['data_index', 'model_completion', 'model_completion_ids', 'full_input_text', 'lookback_ratio'])

# %%
lbr[0]["lookback_ratio"][0][0]
# Out:
# tensor([   nan, 0.2249, 0.2996, 0.4004, 0.4331, 0.2642, 0.2356, 0.2371, 0.3269,
#         0.3630, 0.3896, 0.4370, 0.3867, 0.2739, 0.2388, 0.3044, 0.3967, 0.2900,
#         0.2529, 0.3374, 0.3062, 0.1873, 0.3916, 0.2932, 0.4277, 0.4634, 0.4050,
#         0.4358, 0.4214, 0.2983, 0.3904, 0.3948])

# %%
lbr2 = torch.load("lookback-ratio-cnndm-7b-v2.pt")

# %%
lbr2[0]["lookback_ratio"][0][0]
# Out:
# tensor([1.0000, 0.2249, 0.2996, 0.4004, 0.4331, 0.2642, 0.2356, 0.2371, 0.3269,
#         0.3630, 0.3896, 0.4370, 0.3867, 0.2739, 0.2388, 0.3044, 0.3967, 0.2900,
#         0.2529, 0.3374, 0.3062, 0.1873, 0.3916, 0.2932, 0.4277, 0.4634, 0.4050,
#         0.4358, 0.4214, 0.2983, 0.3904, 0.3948])
